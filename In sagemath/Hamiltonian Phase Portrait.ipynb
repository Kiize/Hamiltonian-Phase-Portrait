# %%
p, q = var('p q')
g = 0.1
H(p, q) = p^2 + 1/q^2
streamline_plot((H.diff(p), -H.diff(q)), (q, -10, 10), (p, -10, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
H.diff(q)
H.diff(p)
# Out:
# (p, q) |--> 2*p
